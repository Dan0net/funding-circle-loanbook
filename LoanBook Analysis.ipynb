# %%
import pandas as pd
import numpy as np
from collections import Counter
from sklearn.ensemble import ExtraTreesClassifier, ExtraTreesRegressor, AdaBoostClassifier, AdaBoostRegressor
import datetime 
from bs4 import BeautifulSoup
import re
from sklearn.model_selection import cross_val_predict
import sklearn.metrics as metrics

# %% [markdown]
# ### Read, clean and convert loanbook

# %%
df = pd.read_csv('loanbook.csv')

# only 2012 dates onwards
df = df[pd.to_datetime(df['loan_accepted_date']) > datetime.date(year=2012, month=1, day=1)]

# ignore repaying (possible over simplification)
# df = df[df['status'] != 'loan: repaying']
df = df[(df['status'] != 'repaying') | (df['payments_remaining'] < df['term']*0.1)]

# select only status text
df['status'] = df['status'].str[6:]

# independent successful overall repayment
df['success'] = (df['status'] == 'repaid') | (df['status'] == 'repaying')

# clean purpose, sector, location
df['loan_purpose'] = df['loan_purpose'].str.lower().str.replace('/', ' ')
df['sector'] = df['sector'].str.lower().str.replace('/', ' ')
df['region_name'] = df['region_name'].str.lower()

# risk band simplification
df['credit_band'] = df['credit_band'].str[:2]

print(df['status'].value_counts())
print(df['success'].value_counts())
df.tail(50)
# Out:
# repaying     19844
# repaid        7005
# defaulted     1131
# late           343
# Name: status, dtype: int64
# True     26849
# False     1474
# Name: success, dtype: int64
#           id    status credit_band        loan_purpose  \
# 28772  32701  repaying          A   refinancing a loan
# 28773  32702  repaying          A     expansion growth
# 28774  32703  repaying          A          tax payment
# 28775  32704  repaying           D     working capital
# 28776  32705  repaying          C      working capital
# 28777  32706  repaying          B     expansion growth
# 28778  32707  repaying          A+     working capital
# 28779  32708  repaying          A     expansion growth
# 28780  32709  repaying          A     expansion growth
# 28781  32710  repaying          B     expansion growth
# 28782  32711  repaying          B      working capital
# 28783  32712  repaying          A+     working capital
# 28784  32713  repaying          B     expansion growth
# 28785  32714  repaying          A     expansion growth
# 28786  32715  repaying          B      working capital
# 28787  32716  repaying          A     expansion growth
# 28788  32717  repaying          B     expansion growth
# 28789  32718  repaying          C      working capital
# 28790  32719  repaying          B          tax payment
# 28791  32720  repaying          B     expansion growth
# 28792  32721  repaying          C     expansion growth
# 28793  32722  repaying          A+    expansion growth
# 28794  32723  repaying          B                other
# 28795  32724  repaying          A+       asset finance
# 28796  32725  repaying          C        asset finance
# 28797  32726  repaying          B      working capital
# 28798  32727  repaying          A     expansion growth
# 28799  32728  repaying          B     expansion growth
# 28800  32729  repaying          A      working capital
# 28801  32730  repaying          B     expansion growth
# 28802  32731  repaying          A     expansion growth
# 28803  32732  repaying          A     expansion growth
# 28804  32733  repaying          B     expansion growth
# 28805  32734  repaying          A+     working capital
# 28806  32735  repaying          A     expansion growth
# 28807  32736  repaying          A+     working capital
# 28808  32737  repaying          A+    expansion growth
# 28809  32738  repaying          A+    expansion growth
# 28810  32739  repaying          A+  refinancing a loan
# 28811  32740  repaying          A     expansion growth
# 28812  32741  repaying          A      working capital
# 28813  32742  repaying          A     expansion growth
# 28814  32743  repaying          A+    expansion growth
# 28815  32744  repaying          A+    expansion growth
# 28816  32745  repaying          B   refinancing a loan
# 28817  32746  repaying          C        asset finance
# 28818  32747  repaying          A      working capital
# 28819  32748  repaying           D    expansion growth
# 28820  32749  repaying          A+     working capital
# 28821  32750  repaying          A     expansion growth
#
#                                   sector                  business_type_name  \
# 28772                         automotive                     Limited Company
# 28773          property and construction                     Limited Company
# 28774  professional and business support                     Limited Company
# 28775  professional and business support                     Limited Company
# 28776          property and construction                     Limited Company
# 28777         i.t and telecommunications                     Limited Company
# 28778      manufacturing and engineering                     Limited Company
# 28779                             retail                     Limited Company
# 28780                             retail       Limited Liability Partnership
# 28781            transport and logistics                     Limited Company
# 28782          property and construction                     Limited Company
# 28783                        agriculture                         Non-Limited
# 28784         i.t and telecommunications                     Limited Company
# 28785                             retail                     Limited Company
# 28786      manufacturing and engineering                     Limited Company
# 28787      manufacturing and engineering  Partnership (less than 4 partners)
# 28788  professional and business support                     Limited Company
# 28789                  consumer services                     Limited Company
# 28790  professional and business support                     Limited Company
# 28791                  consumer services                     Limited Company
# 28792                             retail                     Limited Company
# 28793      manufacturing and engineering                     Limited Company
# 28794                        agriculture                     Limited Company
# 28795      manufacturing and engineering                     Limited Company
# 28796      manufacturing and engineering                     Limited Company
# 28797                             retail                     Limited Company
# 28798                         healthcare                     Limited Company
# 28799          property and construction                         Non-Limited
# 28800                        agriculture  Partnership (less than 4 partners)
# 28801              leisure & hospitality                     Limited Company
# 28802                         healthcare                     Limited Company
# 28803               education & training                     Limited Company
# 28804          property and construction                     Limited Company
# 28805              leisure & hospitality                     Limited Company
# 28806          property and construction                     Limited Company
# 28807         i.t and telecommunications                     Limited Company
# 28808  professional and business support                     Limited Company
# 28809                  consumer services                     Limited Company
# 28810                             retail                     Limited Company
# 28811          property and construction                     Limited Company
# 28812                            finance                     Limited Company
# 28813  professional and business support                     Limited Company
# 28814               education & training                     Limited Company
# 28815  professional and business support                     Limited Company
# 28816      manufacturing and engineering                     Limited Company
# 28817            transport and logistics                     Limited Company
# 28818  professional and business support                     Limited Company
# 28819            transport and logistics                     Limited Company
# 28820               education & training                     Limited Company
# 28821              leisure & hospitality                     Limited Company
#
#             region_name  loan_amount  recoveries  interest_rate   ...    \
# 28772             wales     105000.0         0.0            9.0   ...
# 28773        south east      31500.0         0.0            9.0   ...
# 28774        south east      52500.0         0.0            9.0   ...
# 28775          midlands     110000.0         0.0           17.9   ...
# 28776          midlands       5275.0         0.0           12.5   ...
# 28777          midlands      52500.0         0.0           10.0   ...
# 28778        north east      78000.0         0.0            7.5   ...
# 28779            london      21000.0         0.0            9.0   ...
# 28780            london      84000.0         0.0            9.0   ...
# 28781        north east      26500.0         0.0           10.5   ...
# 28782        south east      52250.0         0.0            9.5   ...
# 28783  northern ireland      41600.0         0.0            7.5   ...
# 28784          midlands      31500.0         0.0           10.0   ...
# 28785        south west     174204.0         0.0            9.0   ...
# 28786          midlands      15900.0         0.0           10.5   ...
# 28787          midlands      63000.0         0.0            9.0   ...
# 28788            london     144894.0         0.0           10.5   ...
# 28789        north west      15900.0         0.0           13.5   ...
# 28815                  NaN      Amortising              1.0            1993.0
# 28816                  NaN      Amortising              1.0            2011.0
# 28817                27296      Amortising              1.0            2013.0
# 28818                15242      Amortising              1.0            2010.0
# 28819                  NaN      Amortising              1.0            2014.0
# 28820                21456      Amortising              1.0            2002.0
# 28821                  NaN      Amortising              1.0            2011.0
#
#           security_taken success
# 28772  No asset security    True
# 28773  No asset security    True
# 28774  No asset security    True
# 28775  No asset security    True
# 28776  No asset security    True
# 28777  No asset security    True
# 28778  No asset security    True
# 28779  No asset security    True
# 28780  No asset security    True
# 28781  No asset security    True
# 28782  No asset security    True
# 28783  No asset security    True
# 28784  No asset security    True
# 28785  No asset security    True
# 28786  No asset security    True
# 28787  No asset security    True
# 28788  No asset security    True
# 28789  No asset security    True
# 28790  No asset security    True
# 28791  No asset security    True
# 28792  No asset security    True
# 28793  No asset security    True
# 28794  No asset security    True
# 28795  No asset security    True
# 28796  No asset security    True
# 28797  No asset security    True
# 28798  No asset security    True
# 28799  No asset security    True
# 28800  No asset security    True
# 28801  No asset security    True
# 28802  No asset security    True
# 28803  No asset security    True
# 28804  No asset security    True
# 28805  No asset security    True
# 28806  No asset security    True
# 28807  No asset security    True
# 28808  No asset security    True
# 28809  No asset security    True
# 28810  No asset security    True
# 28811  No asset security    True
# 28812  No asset security    True
# 28813  No asset security    True
# 28814  No asset security    True
# 28815  No asset security    True
# 28816  No asset security    True
# 28817  No asset security    True
# 28818  No asset security    True
# 28819  No asset security    True
# 28820  No asset security    True
# 28821  No asset security    True
#
# [50 rows x 26 columns]

# %% [markdown]
# ### Generate one hot encodings for text terms
#
# This is to understand the `loan_purpose` and `sector` fields, which are written inconsistently.
#
# First extract the most common terms, then generate a dataframe with one hot encoding per row.

# %%
# extract terms across dataframe column
def term_extraction(df_col, min_size=1, min_count=5):
    words = df_col.tolist()
    words = [x if type(x) is str else '' for x in words]
    words_join = ' '.join(words).split(' ')
    terms = Counter(words_join).most_common(20)
    
    terms = [t for t, c in terms if (len(t) > min_size and c > min_count)]
    
    return terms, words

purpose_terms, purpose_words = term_extraction(df['loan_purpose'])
sector_terms, sector_words = term_extraction(df['sector'])
    
# generate one hot dataframe representation
def term_onehot_generator(words, index, terms=purpose_terms, prepend='purpose_'):
    m = np.zeros((len(words), len(terms)))

    for i, row in enumerate(words):
        m[i,:] = [int(t in row) for t in terms]

    return pd.DataFrame(data=m, index=index, columns=[prepend + t for t in terms])

df_purpose = term_onehot_generator(purpose_words, df.index, terms=purpose_terms, prepend='purpose_')
df_sector = term_onehot_generator(sector_words, df.index, terms=sector_terms, prepend='sector_')

# %% [markdown]
# ### Generate X and y dataframes for estimation

# %%
# one hot credit dataframe
df_credit_onehot = pd.get_dummies(df['credit_band'])
df_region_onehot = pd.get_dummies(df['region_name'])

# select continuous columns
df_cont = df[['loan_amount', 'interest_rate', 'term']]

# concatenate dataframes for X
X = pd.concat([df_purpose, df_sector, df_credit_onehot, df_region_onehot, df_cont], axis=1)

# concatenate encoding for success and status
y = pd.concat([pd.get_dummies(df['status']), df['success']], axis=1)
# y = df['success']

print(df_purpose.shape, df_credit_onehot.shape, df_cont.shape)
print(X.shape, y.shape)
# Out:
# (28323, 18) (28323, 6) (28323, 3)
# (28323, 56) (28323, 5)

# %% [markdown]
# ### Learn prediction model
#
# We use a basic ExtraTrees Regression model from scikit-learn

# %%
clfs = {col: AdaBoostRegressor() for col in y.columns.values}

for col, clf in clfs.items():
    clf.fit(X, y[col])
    
    preds = cross_val_predict(clf, X, y[col], cv=5)
    scores = metrics.accuracy_score(np.round(preds), y[col])
    print('%s, binary decision accuracy : %.2f+/-%.2f' %(col, np.mean(scores), np.std(scores)))

for col, clf in clfs.items():
    col = col.ljust(10)
    print("%s feature importances" % (col))
    clf_fi = clf.feature_importances_
    clf_fi_order = np.argsort(clf_fi)[::-1][:10]
    for c, v in zip(np.array(X.columns.values)[clf_fi_order], clf_fi[clf_fi_order]):
        print('%s %s: %.4f' % (col, c, v))
# Out:
# defaulted, binary decision accuracy : 0.96+/-0.00
# repaid, binary decision accuracy : 0.71+/-0.00
# success, binary decision accuracy : 0.95+/-0.00
# repaying, binary decision accuracy : 0.65+/-0.00
# late, binary decision accuracy : 0.99+/-0.00
# defaulted  feature importances
# defaulted  purpose_capital: 0.4457
# defaulted  A+: 0.2946
# defaulted  interest_rate: 0.1091
# defaulted  A : 0.0771
# defaulted  term: 0.0286
# defaulted  B : 0.0226
# defaulted  loan_amount: 0.0156
# defaulted  scotland: 0.0028
# defaulted  purpose_other: 0.0013
# defaulted  purpose_expansion: 0.0012
# repaid     feature importances
# repaid     term: 0.7312
# repaid     purpose_capital: 0.1095
# repaid     purpose_residential: 0.0511
# repaid     interest_rate: 0.0399
# repaid     sector_other: 0.0372
# repaid     A+: 0.0158
# repaid     purpose_expansion: 0.0079
# repaid     purpose_purchase: 0.0074
# repaid     northern ireland: 0.0000
# repaid     purpose_tax: 0.0000
# success    feature importances
# success    interest_rate: 0.4391
# success    purpose_capital: 0.3126
# success    A+: 0.1261
# success    purpose_growth: 0.0752
# success    term: 0.0239
# success    loan_amount: 0.0077
# success    north west: 0.0069
# success    A : 0.0054
# success    scotland: 0.0022
# success    purpose_short: 0.0008
# repaying   feature importances
# repaying   term: 0.6126
# repaying   purpose_capital: 0.1249
# repaying   purpose_expansion: 0.0575
# repaying   purpose_working: 0.0477
# repaying   A+: 0.0404
# repaying   purpose_residential: 0.0336
# repaying   interest_rate: 0.0333
# repaying   sector_other: 0.0258
# repaying   purpose_growth: 0.0189
# repaying   purpose_purchase: 0.0052
# late       feature importances
# late       purpose_property: 0.3804
# late       interest_rate: 0.2014
# late       north west: 0.1893
# late       purpose_short: 0.1723
# late       loan_amount: 0.0299
# late       E: 0.0131
# late       purpose_loan: 0.0053
# late       sector_healthcare: 0.0036
# late       purpose_development: 0.0031
# late       sector_manufacturing: 0.0016

# %% [markdown]
# ### Predictor for new data
#
# Generates a dataframe for some new data and prints the estimated return.
#
# Returns are crudely generated by `rate` \* `success` \* (1.0 - `CF_FEE`),
#
# where `success` is is the likelihood of the loan being repaid (ie. not defauling or being late)

# %%
def predict(
    purpose = 'Working Capital Loan', 
    sector = 'Manufacturing and Engineering', 
    location = 'London',
    risk = 'A+', 
    amount = 52000, 
    term = 60, 
    rate = 7.5):
    print('%s | %s | %s | %s | %d | %dm | %.1f%%' % (purpose, sector, location, risk, amount, term, rate))
    print('-----')
    ln_purpose = term_onehot_generator([purpose.strip().lower()], [0], terms=purpose_terms, prepend='purpose_')
    ln_sector = term_onehot_generator([sector.strip().lower()], [0], terms=sector_terms, prepend='sector_')
    ln_credit_onehot = pd.DataFrame([[int(c == risk.strip().lower().ljust(2)) for c in df_credit_onehot.columns.values]], columns=df_credit_onehot.columns.values)
    ln_region_onehot = pd.DataFrame([[int(c == location.strip().lower().lower()) for c in df_region_onehot.columns.values]], columns=df_region_onehot.columns.values)
    
    ln_cont = pd.DataFrame([[amount, rate, term]], columns=df_cont.columns.values)

    ln = pd.concat([ln_purpose, ln_sector, ln_credit_onehot, ln_region_onehot, ln_cont], axis=1)
    
    proba = clfs['success'].predict(ln)[0]
    print('success ~ %.2f%%' %(proba*100.0))
    print('return  ~ %.3f%%   (= %.4f * %.4f * .90)' % (rate *.9 * proba, rate, proba))
    
    print(' | '.join(['%s ~ %.0f%%' % (col, clfs[col].predict(ln)[0]*100.0) for col in ['defaulted', 'late', 'repaid', 'repaying']]))
    print('-----\n\n')

# %% [markdown]
# ### Pre-defined examples to show some outcomes

# %%
predict(
    purpose = 'Working Capital Loan', 
    sector = 'Manufacturing and Engineering', 
    location = 'London',
    risk = 'A+', 
    amount = 52000, 
    term = 60, 
    rate = 7.5)

predict(
    purpose = 'Expansion And Growth Loan ', 
    sector = 'Retail', 
    location = 'London',
    risk = 'B', 
    amount = 262500, 
    term = 60, 
    rate = 10.5)

predict(
    purpose = 'Expansion And Growth Loan ', 
    sector = 'Wholesale',
    location = 'South East',
    risk = 'B', 
    amount = 21200, 
    term = 60, 
    rate = 10.5)

predict(
    purpose = 'Working Capital Loan ', 
    sector = 'Retail', 
    location = 'South East',
    risk = 'B', 
    amount = 21200, 
    term = 60, 
    rate = 10.5)
# Out:
# Working Capital Loan | Manufacturing and Engineering | London | A+ | 52000 | 60m | 7.5%
# -----
# success ~ 95.21%
# return  ~ 6.427%   (= 7.5000 * 0.9521 * .90)
# defaulted ~ 9% | late ~ 1% | repaid ~ 33% | repaying ~ 73%
# -----
#
#
# Expansion And Growth Loan  | Retail | London | B | 262500 | 60m | 10.5%
# -----
# success ~ 95.32%
# return  ~ 9.007%   (= 10.5000 * 0.9532 * .90)
# defaulted ~ 2% | late ~ 1% | repaid ~ 20% | repaying ~ 81%
# -----
#
#
# Expansion And Growth Loan  | Wholesale | South East | B | 21200 | 60m | 10.5%
# -----
# success ~ 95.32%
# return  ~ 9.007%   (= 10.5000 * 0.9532 * .90)
# defaulted ~ 2% | late ~ 1% | repaid ~ 20% | repaying ~ 81%
# -----
#
#
# Working Capital Loan  | Retail | South East | B | 21200 | 60m | 10.5%
# -----
# success ~ 95.21%
# return  ~ 8.998%   (= 10.5000 * 0.9521 * .90)
# defaulted ~ 9% | late ~ 1% | repaid ~ 20% | repaying ~ 73%
# -----

# %% [markdown]
# # Predict from an HTML file
#
# To use this function, save your current Funding Circle loanbook page `https://www.fundingcircle.com/lend/loan-requests/` to `fc-lb.html`.
#
# Each loan row will be predicted for.

# %%
soup = BeautifulSoup(open('fc-lr.html'), 'html.parser')
for elem in soup.find_all(id=re.compile('auction')):
    sector_location_uid = elem('span')[0].contents[0].strip().split(',')
    
    purpose = elem('a')[1].contents[0].strip().lower()
    sector = sector_location_uid[0].strip().lower()
    location = sector_location_uid[1].split('-')[0].strip().lower()
    risk = elem('td')[2].contents[0].strip()
    
    amount = int(elem('td')[3].contents[0].strip().replace(',','')[1:])
    term = int(elem('td')[4].contents[0].strip())
    rate = float(elem('td')[5].contents[0].strip()[:-1])
    
    uid = sector_location_uid[1].split('-')[1].strip()
    
    print('loan id: %s' % (uid))
    predict(purpose, sector, location, risk, amount, term, rate)
# Out:
# loan id: 33145
# expansion and growth loan | manufacturing and engineering | midlands | B | 106000 | 60m | 10.5%
# -----
# success ~ 95.32%
# return  ~ 9.007%   (= 10.5000 * 0.9532 * .90)
# defaulted ~ 2% | late ~ 1% | repaid ~ 20% | repaying ~ 81%
# -----
#
#
# loan id: 33006
# expansion and growth loan | retail | london | B | 262500 | 60m | 10.5%
# -----
# success ~ 95.32%
# return  ~ 9.007%   (= 10.5000 * 0.9532 * .90)
# defaulted ~ 2% | late ~ 1% | repaid ~ 20% | repaying ~ 81%
# -----
#
#
# loan id: 33098
# expansion and growth loan | wholesale | south east | B | 212000 | 60m | 10.5%
# -----
# success ~ 95.32%
# return  ~ 9.007%   (= 10.5000 * 0.9532 * .90)
# defaulted ~ 2% | late ~ 1% | repaid ~ 20% | repaying ~ 81%
# -----
#
#
# loan id: 33127
# expansion and growth loan | manufacturing and engineering | south east | B | 43258 | 60m | 10.5%
# -----
# success ~ 95.32%
# return  ~ 9.007%   (= 10.5000 * 0.9532 * .90)
# defaulted ~ 2% | late ~ 1% | repaid ~ 20% | repaying ~ 81%
# -----
#
#
# loan id: 33115
# expansion and growth loan | wholesale | south east | B | 146865 | 60m | 10.5%
# -----
# success ~ 95.32%
# return  ~ 9.007%   (= 10.5000 * 0.9532 * .90)
# defaulted ~ 2% | late ~ 1% | repaid ~ 20% | repaying ~ 81%
# -----
#
#
# loan id: 33110
# property development in uxbridge 7 | property and construction | london | A | 93900 | 12m | 10.0%
# -----
# success ~ 95.32%
# return  ~ 8.578%   (= 10.0000 * 0.9532 * .90)
# defaulted ~ 2% | late ~ 1% | repaid ~ 56% | repaying ~ 41%
# -----
#
#
# loan id: 33111
# expansion and growth loan | wholesale | london | B | 41800 | 24m | 9.5%
# -----
# success ~ 98.03%
# return  ~ 8.381%   (= 9.5000 * 0.9803 * .90)
# defaulted ~ 2% | late ~ 1% | repaid ~ 30% | repaying ~ 63%
# -----
#
#
# loan id: 33094
# working capital loan | transport and logistics | south east | A | 26250 | 60m | 9.0%
# -----
# success ~ 95.21%
# return  ~ 7.712%   (= 9.0000 * 0.9521 * .90)
# defaulted ~ 9% | late ~ 1% | repaid ~ 20% | repaying ~ 73%
# -----
#
#
# loan id: 33109
# property development in exmouth devon 3 | property and construction | midlands | A+ | 342480 | 18m | 9.0%
# -----
# success ~ 98.03%
# return  ~ 7.940%   (= 9.0000 * 0.9803 * .90)
# defaulted ~ 2% | late ~ 3% | repaid ~ 41% | repaying ~ 50%
# -----
#
#
# loan id: 33122
# short term property loan wisborough green 1 | property and construction | south east | A+ | 349765 | 12m | 9.0%
# -----
# success ~ 98.03%
# return  ~ 7.940%   (= 9.0000 * 0.9803 * .90)
# defaulted ~ 2% | late ~ 0% | repaid ~ 56% | repaying ~ 41%
# -----
#
#
# loan id: 33022
# expansion and growth loan | retail | london | A | 84000 | 60m | 9.0%
# -----
# success ~ 98.03%
# return  ~ 7.940%   (= 9.0000 * 0.9803 * .90)
# defaulted ~ 2% | late ~ 1% | repaid ~ 20% | repaying ~ 81%
# -----
#
#
# loan id: 33015
# working capital loan | retail | east anglia | A | 131250 | 60m | 9.0%
# -----
# success ~ 95.21%
# return  ~ 7.712%   (= 9.0000 * 0.9521 * .90)
# defaulted ~ 9% | late ~ 1% | repaid ~ 20% | repaying ~ 73%
# -----
#
#
# loan id: 32993
# working capital loan | retail | midlands | A | 87436 | 60m | 9.0%
# -----
# success ~ 95.21%
# return  ~ 7.712%   (= 9.0000 * 0.9521 * .90)
# defaulted ~ 9% | late ~ 1% | repaid ~ 20% | repaying ~ 73%
# -----
#
#
# loan id: 33140
# expansion and growth loan | property and construction | midlands | A | 105000 | 60m | 9.0%
# -----
# success ~ 98.03%
# return  ~ 7.940%   (= 9.0000 * 0.9803 * .90)
# defaulted ~ 2% | late ~ 1% | repaid ~ 20% | repaying ~ 81%
# -----
#
#
# loan id: 32995
# working capital loan | property and construction | south east | A | 367500 | 60m | 9.0%
# -----
# success ~ 95.21%
# return  ~ 7.712%   (= 9.0000 * 0.9521 * .90)
# defaulted ~ 9% | late ~ 3% | repaid ~ 20% | repaying ~ 73%
# -----
#
#
# loan id: 32982
# working capital loan | professional and business support | south east | A | 364000 | 36m | 8.5%
# -----
# success ~ 95.21%
# return  ~ 7.284%   (= 8.5000 * 0.9521 * .90)
# defaulted ~ 9% | late ~ 3% | repaid ~ 46% | repaying ~ 52%
# -----
#
#
# loan id: 33070
# property development in leicester 1 | property and construction | midlands | A+ | 289380 | 12m | 8.0%
# -----
# success ~ 98.03%
# return  ~ 7.058%   (= 8.0000 * 0.9803 * .90)
# defaulted ~ 0% | late ~ 1% | repaid ~ 56% | repaying ~ 41%
# -----
#
#
# loan id: 33096
# property development in colchester 4 | property and construction | midlands | A+ | 264920 | 10m | 8.0%
# -----
# success ~ 98.03%
# return  ~ 7.058%   (= 8.0000 * 0.9803 * .90)
# defaulted ~ 0% | late ~ 1% | repaid ~ 56% | repaying ~ 41%
# -----
#
#
# loan id: 33112
# expansion and growth loan | property and construction | north east | A+ | 15600 | 60m | 7.5%
# -----
# success ~ 98.03%
# return  ~ 6.617%   (= 7.5000 * 0.9803 * .90)
# defaulted ~ 0% | late ~ 1% | repaid ~ 33% | repaying ~ 81%
# -----
#
#
# loan id: 33137
# expansion and growth loan | property and construction | scotland | A+ | 78000 | 60m | 7.5%
# -----
# success ~ 98.03%
# return  ~ 6.617%   (= 7.5000 * 0.9803 * .90)
# defaulted ~ 0% | late ~ 1% | repaid ~ 33% | repaying ~ 81%
# -----
#
#
# loan id: 33128
# working capital loan | i.t and telecommunications | midlands | A+ | 31200 | 60m | 7.5%
# -----
# success ~ 95.21%
# return  ~ 6.427%   (= 7.5000 * 0.9521 * .90)
# defaulted ~ 9% | late ~ 1% | repaid ~ 33% | repaying ~ 73%
# -----
#
#
# loan id: 33125
# expansion and growth loan | property and construction | south east | A+ | 208000 | 60m | 7.5%
# -----
# success ~ 98.03%
# return  ~ 6.617%   (= 7.5000 * 0.9803 * .90)
# defaulted ~ 0% | late ~ 1% | repaid ~ 33% | repaying ~ 81%
# -----
#
#
# loan id: 32984
# expansion and growth loan | leisure & hospitality | london | A+ | 52000 | 60m | 7.5%
# -----
# success ~ 98.03%
# return  ~ 6.617%   (= 7.5000 * 0.9803 * .90)
# defaulted ~ 0% | late ~ 1% | repaid ~ 33% | repaying ~ 81%
# -----
#
#
# loan id: 33139
# working capital loan | professional and business support | midlands | A+ | 103500 | 48m | 7.0%
# -----
# success ~ 95.21%
# return  ~ 5.999%   (= 7.0000 * 0.9521 * .90)
# defaulted ~ 9% | late ~ 1% | repaid ~ 33% | repaying ~ 73%
# -----
#
#
# loan id: 33135
# expansion and growth loan | retail | midlands | A+ | 205375 | 36m | 6.5%
# -----
# success ~ 98.03%
# return  ~ 5.735%   (= 6.5000 * 0.9803 * .90)
# defaulted ~ 0% | late ~ 1% | repaid ~ 30% | repaying ~ 63%
# -----
#
#
# loan id: 33146
# working capital loan | leisure & hospitality | south east | A+ | 61800 | 36m | 6.5%
# -----
# success ~ 95.21%
# return  ~ 5.570%   (= 6.5000 * 0.9521 * .90)
# defaulted ~ 9% | late ~ 1% | repaid ~ 46% | repaying ~ 52%
# -----
#
#
# loan id: 33124
# expansion and growth loan | automotive | london | A+ | 51250 | 24m | 6.5%
# -----
# success ~ 98.03%
# return  ~ 5.735%   (= 6.5000 * 0.9803 * .90)
# defaulted ~ 0% | late ~ 1% | repaid ~ 30% | repaying ~ 63%
# -----
#
#
# loan id: 33065
# expansion and growth loan | i.t and telecommunications | midlands | A+ | 103000 | 36m | 6.5%
# -----
# success ~ 98.03%
# return  ~ 5.735%   (= 6.5000 * 0.9803 * .90)
# defaulted ~ 0% | late ~ 1% | repaid ~ 30% | repaying ~ 63%
# -----
#
#
# loan id: 33079
# working capital loan | transport and logistics | london | A+ | 51000 | 12m | 5.5%
# -----
# success ~ 95.21%
# return  ~ 4.713%   (= 5.5000 * 0.9521 * .90)
# defaulted ~ 9% | late ~ 1% | repaid ~ 41% | repaying ~ 52%
# -----
